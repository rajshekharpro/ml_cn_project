# %% [markdown]
# ## Cosine similarity anisotropy

# %%
import os
import torch
import torch.nn.functional as F
import pickle
import numpy as np
import random
import argparse
from tqdm import tqdm

# %%
# !ls ../../YaTC/embeddings
# Out:
# train_emb_5.pkl  train_emb_co.pkl  train_emb.pkl

# %%
def cos_contrib(emb1, emb2):
    numerator_terms = emb1 * emb2
    denom = np.linalg.norm(emb1) * np.linalg.norm(emb2)
    return np.array(numerator_terms / denom)


def measure_anisotropy(filepath):
    with open(filepath, "rb") as f:
        embeddings, _ = pickle.load(f)
    
    indices = torch.randperm(embeddings.size(0))
    embeddings = embeddings[indices]
    
    layer_cosine_contribs = []

    for i in tqdm(range(embeddings.shape[0] - 1)):
        emb1, emb2 = embeddings[i, :], embeddings[i+1, :]
        layer_cosine_contribs.append(cos_contrib(emb1, emb2))
    
    layer_cosine_contribs = np.stack(layer_cosine_contribs)
    layer_cosine_contribs_mean = layer_cosine_contribs.mean(axis=0)
    
    aniso = layer_cosine_contribs_mean.sum()    
    top_dims = np.argsort(layer_cosine_contribs_mean)[-10:]
    top_dims = np.flip(top_dims)
    
    print(f"### {filepath} ###")
    print(f"Top 10 dims: {top_dims}")
    print(f"Estimated anisotropy: {aniso}")
    for i in range(10):
        d = top_dims[i]
        print(d, layer_cosine_contribs_mean[d])

# %% [markdown]
# ### YaTC

# %%
# !ls /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_test
# Out:
# test_emb_co.pkl

# %%
directory = '/mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb'
for filename in os.listdir(directory):
    filepath = os.path.join(directory, filename)
    print(filepath)
    result = measure_anisotropy(filepath)
    print(f"{filename} - {result}")
# Out:
# /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb/test_emb_30k.pkl
# torch.Size([265728, 192])
# 100%|██████████| 265727/265727 [00:06<00:00, 42803.08it/s]
# ### /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb/test_emb_30k.pkl ###
# Top 10 dims: [ 71 191  32 136  29  55  43 107 104 159]
# Estimated anisotropy: 0.9888208508491516
# 71 0.3379453
# 191 0.07295155
# 32 0.07191483
# 136 0.058201995
# 29 0.05297095
# 55 0.016966699
# 43 0.016555395
# 107 0.015520952
# 104 0.015392051
# 159 0.013206995
# test_emb_30k.pkl - None
# /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb/test_emb_50k.pkl
# torch.Size([265728, 192])
# 100%|██████████| 265727/265727 [00:06<00:00, 43343.44it/s]
# ### /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb/test_emb_50k.pkl ###
# Top 10 dims: [ 71  29 191  32 136 104  55 120 107 111]
# Estimated anisotropy: 0.9952542185783386
# 71 0.694655
# 29 0.13842122
# 191 0.03931236
# 32 0.019699488
# 136 0.013873904
# 104 0.008809212
# 55 0.006952891
# 120 0.0037688722
# 107 0.0036290349
# 111 0.002573764
# test_emb_50k.pkl - None
# /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb/test_emb_40k.pkl
# torch.Size([265728, 192])
# 100%|██████████| 265727/265727 [00:06<00:00, 42354.59it/s]
# ### /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb/test_emb_40k.pkl ###
# Top 10 dims: [ 71  29 191  32 136  55 104 144 106 107]
# Estimated anisotropy: 0.9906669855117798
# 71 0.55955696
# 29 0.08051398
# 191 0.067226015
# 32 0.05446266
# 136 0.046188854
# 55 0.012382428
# 104 0.010446285
# 144 0.006013514
# 106 0.0057103327
# 107 0.005456783
# test_emb_40k.pkl - None
# /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb/test_emb_20k.pkl
# torch.Size([265728, 192])
# 100%|██████████| 265727/265727 [00:06<00:00, 43295.13it/s]
# ### /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb/test_emb_20k.pkl ###
# Top 10 dims: [ 71 136  32 191 159  63 133  43 120  56]
# Estimated anisotropy: 0.9677963852882385
# 71 0.118026406
# 136 0.058172856
# 32 0.049852584
# 191 0.032911498
# 159 0.030996611
# 63 0.024036242
# 133 0.021719549
# 43 0.020452928
# 120 0.01960117
# 56 0.018945131
# test_emb_20k.pkl - None
# /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb/test_emb_10k.pkl
# torch.Size([265728, 192])
# 100%|██████████| 265727/265727 [00:06<00:00, 42568.65it/s]
# ### /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb/test_emb_10k.pkl ###
# Top 10 dims: [ 71 100  76 114  42 144  63  18   9 136]
# Estimated anisotropy: 0.9369312524795532
# 71 0.04490188
# 100 0.032694757
# 76 0.025953477
# 114 0.025613636
# 42 0.024121873
# 144 0.021296538
# 63 0.01949331
# 18 0.017240964
# 9 0.016526794
# 136 0.016375858
# test_emb_10k.pkl - None

# %%
directory = '/mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_train'
for filename in os.listdir(directory):
    filepath = os.path.join(directory, filename)
    print(filepath)
    result = measure_anisotropy(filepath)
    print(f"{filename} - {result}")
# Out:
# /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_train/test_emb_30k.pkl
# torch.Size([265728, 192])
# 100%|██████████| 265727/265727 [00:07<00:00, 36122.33it/s]
# ### /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_train/test_emb_30k.pkl ###
# Top 10 dims: [ 71 191  32 136  29  55  43 107 104 159]
# Estimated anisotropy: 0.988823652267456
# 71 0.33798787
# 191 0.07295519
# 32 0.07190427
# 136 0.058195002
# 29 0.05296276
# 55 0.016972981
# 43 0.01655207
# 107 0.01551607
# 104 0.015392801
# 159 0.013208796
# test_emb_30k.pkl - None
# /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_train/test_emb_50k.pkl
# torch.Size([265728, 192])
# 100%|██████████| 265727/265727 [00:07<00:00, 34229.17it/s]
# ### /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_train/test_emb_50k.pkl ###
# Top 10 dims: [ 71  29 191  32 136 104  55 120 107 111]
# Estimated anisotropy: 0.9952740669250488
# 71 0.69466203
# 29 0.13840808
# 191 0.039315853
# 32 0.019695535
# 136 0.013875553
# 104 0.008808964
# 55 0.0069536855
# 120 0.0037685395
# 107 0.003628457
# 111 0.0025732792
# test_emb_50k.pkl - None
# /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_train/test_emb_40k.pkl
# torch.Size([265728, 192])
# 100%|██████████| 265727/265727 [00:08<00:00, 31608.98it/s]
# ### /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_train/test_emb_40k.pkl ###
# Top 10 dims: [ 71  29 191  32 136  55 104 144 106 107]
# Estimated anisotropy: 0.9906506538391113
# 71 0.5596321
# 29 0.08050955
# 191 0.06723529
# 32 0.05445611
# 136 0.046181243
# 55 0.012385842
# 104 0.010442196
# 144 0.0060113827
# 106 0.005705349
# 107 0.005457998
# test_emb_40k.pkl - None
# /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_train/test_emb_20k.pkl
# torch.Size([265728, 192])
# 100%|██████████| 265727/265727 [00:06<00:00, 39807.77it/s]
# ### /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_train/test_emb_20k.pkl ###
# Top 10 dims: [ 71 136  32 191 159  63 133  43 120  56]
# Estimated anisotropy: 0.9678266048431396
# 71 0.11805012
# 136 0.058154993
# 32 0.049859215
# 191 0.03293315
# 159 0.031001985
# 63 0.024048576
# 133 0.021715496
# 43 0.020446535
# 120 0.01960582
# 56 0.018953033
# test_emb_20k.pkl - None
# /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_train/test_emb_10k.pkl
# torch.Size([265728, 192])
# 100%|██████████| 265727/265727 [00:06<00:00, 41735.58it/s]
# ### /mnt/bigdisk/mayank/netmamba_pretrain/YaTC/emb_train/test_emb_10k.pkl ###
# Top 10 dims: [ 71 100  76 114  42 144  63  18   9 136]
# Estimated anisotropy: 0.9369040727615356
# 71 0.04489198
# 100 0.032676537
# 76 0.025949545
# 114 0.02563956
# 42 0.024134912
# 144 0.021294976
# 63 0.019496217
# 18 0.01727614
# 9 0.016530622
# 136 0.016370075
# test_emb_10k.pkl - None

# %% [markdown]
# ### ET-BERT

# %%
directory = '../data/etbert/'
for filename in os.listdir(directory):
    filepath = os.path.join(directory, filename)
    result = measure_anisotropy(filepath)
    print(f"{filename} - {result}")

# %% [markdown]
# ### netFound

# %%
directory = '../data/netfound/'
for filename in os.listdir(directory):
    filepath = os.path.join(directory, filename)
    result = measure_anisotropy(filepath)
    print(f"{filename} - {result}")

# %% [markdown]
# ### netMamba

# %%
directory = '../data/netmamba/'
for filename in os.listdir(directory):
    filepath = os.path.join(directory, filename)
    result = measure_anisotropy(filepath)
    print(f"{filename} - {result}")
